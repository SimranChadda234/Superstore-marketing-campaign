# %% [markdown]
# Project: Superstore Marketing Campaign Dataset.
# Description : Perform Exploratory Data Analysis on the given dataset to get the insights and hidden trends from the data.During the analysis various facts like
# potential customer expenditure per customer etc were figured out.
#
# Candidate Name : 1.Simran Chadda
#                  2.Tanushri Umaji Dhote.

# %% [markdown]
# https://www.kaggle.com/datasets/ahsan81/superstore-marketing-campaign-dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
d=pd.read_csv('/content/superstore_data.csv')

# %%
d.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
d.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    7/3/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0   3/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    1/9/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %% [markdown]
# Data Preprocessing.

# %%
d.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
d.shape
# Out:
# (2240, 22)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
d.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2216.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25173.076661     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
d.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
sns.heatmap(d.isnull())
plt.show()

# %% [markdown]
# From this conclusion white space show null value of data.

# %%
d.nunique()
# Out:
# Id                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Dt_Customer             663
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Response                  2
# Complain                  2
# dtype: int64

# %% [markdown]
# # Data Cleaning.

# %%
plt.hist(d["Year_Birth"],rwidth=0.8)
# Out:
# (array([  3.,   0.,   0.,   0.,  16., 300., 541., 685., 506., 189.]),
#  array([1893. , 1903.3, 1913.6, 1923.9, 1934.2, 1944.5, 1954.8, 1965.1,
#         1975.4, 1985.7, 1996. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Year of Birth
# We assume that the current year is 2023. We find some outliers that seem to make some customers more than 123 years old, so we remove these

# %%
plt.hist(d['Id'],rwidth=0.8)
# Out:
# (array([224., 213., 232., 235., 243., 221., 212., 198., 206., 256.]),
#  array([    0. ,  1119.1,  2238.2,  3357.3,  4476.4,  5595.5,  6714.6,
#          7833.7,  8952.8, 10071.9, 11191. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# We analyses the past year to find the customers id's which are not used currently, so we can remove that id's.

# %% [markdown]
# # Data Visualization

# %%
sns.boxplot(y="Income",x="Education",data=d,orient="vertical")
plt.show()

# %% [markdown]
# AS expected the income spend increase with the increase in education level.

# %%
# Plot Bar Plot for the Students
sns.set_theme(style="whitegrid")
sns.barplot(data = d, y ="Income", x = "Education", palette = "muted")
plt.title("Students")
plt.show()

# %% [markdown]
# We analyse the PhD is the highest income of education.

# %%
d.Response.value_counts()
# Out:
# 0    1906
# 1     334
# Name: Response, dtype: int64

# %%
d.Response.value_counts().plot(kind="bar", color = ["red", "blue"], title =" Response distribution")
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# Zero is the highest count.

# %%
d=d.drop(columns='Id',axis=1)

# %%
d.head()
# Out:
#    Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        1970  Graduation       Divorced  84835.0        0         0
# 1        1961  Graduation         Single  57091.0        0         0
# 2        1958  Graduation        Married  67267.0        0         1
# 3        1967  Graduation       Together  32474.0        1         1
# 4        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  ...  MntFishProducts  \
# 0   6/16/2014        0       189        104  ...              111
# 1   6/15/2014        0       464          5  ...                7
# 2   5/13/2014        0       134         11  ...               15
# 3   11/5/2014        0        10          0  ...                0
# 4    8/4/2014        0         6         16  ...               11
#
#    MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# 0               189           218                  1                4
# ...

# %%
sns.countplot(x=d['Marital_Status'])
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Married is the highest count.

# %%
plt.figure(figsize=(15,16))
sns.countplot(x=d['Year_Birth'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From this conclusion 1976 year is the highest year

# %%
plt.scatter(x="Education",y="Income",data=d)
plt.xlabel('Education')
plt.ylabel('Income')
plt.title('Student')
plt.show()

# %% [markdown]
# From this conclusion graduation is highest income.

# %%
sns.countplot(x="Marital_Status",hue="Education",data=d)

# %% [markdown]
# In this graph it show that married of the graduation degree is the highest.

# %%
d.corr()
# Out:
#                      Year_Birth    Income   Kidhome  Teenhome   Recency  \
# Year_Birth             1.000000 -0.161791  0.230176 -0.352111 -0.019871
# Income                -0.161791  1.000000 -0.428669  0.019133 -0.003970
# Kidhome                0.230176 -0.428669  1.000000 -0.036133  0.008827
# Teenhome              -0.352111  0.019133 -0.036133  1.000000  0.016198
# Recency               -0.019871 -0.003970  0.008827  0.016198  1.000000
# MntWines              -0.157773  0.578650 -0.496297  0.004846  0.016064
# MntFruits             -0.017917  0.430842 -0.372581 -0.176764 -0.004306
# MntMeatProducts       -0.030872  0.584633 -0.437129 -0.261160  0.023056
# MntFishProducts       -0.041625  0.438871 -0.387644 -0.204187  0.001079
# MntSweetProducts      -0.018133  0.440744 -0.370673 -0.162475  0.022670
# MntGoldProds          -0.061818  0.325916 -0.349595 -0.021725  0.016693
# NumDealsPurchases     -0.060846 -0.083101  0.221798  0.387741 -0.001098
# ...

# %%
sns.heatmap(d.corr(),annot=True)

# %% [markdown]
# From this conclusion it show correlation of each column in a dataframe.

# %%
d['Education'].value_counts()
# Out:
# Graduation    1127
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: Education, dtype: int64

# %%
# Education Distribution
fig = px.histogram(d, x='Education', nbins=5, title="Education Distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Fom this conclusion it shows that Graduation is the highest count and basic is the lowest count.

# %%
d['Age'] = 2022 - d['Year_Birth']

# %%
d.head()
# Out:
#    Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        1970  Graduation       Divorced  84835.0        0         0
# 1        1961  Graduation         Single  57091.0        0         0
# 2        1958  Graduation        Married  67267.0        0         1
# 3        1967  Graduation       Together  32474.0        1         1
# 4        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  MntFruits  ...  MntSweetProducts  \
# 0   6/16/2014        0       189        104  ...               189
# 1   6/15/2014        0       464          5  ...                 0
# 2   5/13/2014        0       134         11  ...                 2
# 3   11/5/2014        0        10          0  ...                 0
# 4    8/4/2014        0         6         16  ...                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %% [markdown]
# #Distribution of Age

# %%
fig = px.histogram(d, x="Age",nbins=30,color="Age", title="Distribution of Age")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From this conclusion it shows that age 46 is the highest count.

# %%
# Marital Distribution
fig = px.histogram(d, x='Marital_Status', nbins=5, title="Marital Distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# From this conclusion it shows that married is the highest count.

# %% [markdown]
# Scatter plot of "MntWines" vs "MntSweetProducts" with a "Income"

# %%
# Scatter plot of "MntWines" vs "MntSweetProducts" with a third variable represented by size or color
fig = px.scatter(d, x="MntWines", y="MntSweetProducts", size="NumWebVisitsMonth", color="Income", size_max=50)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The scatter plot shows the relationship between the amount spent on wines and the amount spent on sweet products, with a third variable represented by size. The size of the marker represents the number of web visits per month, and the color of the marker represents the income level
